# %% [markdown]
# # Ejercicios
# Las funciones son poderosas. Intenta escribir algo tú mismo.
#
# Como antes, no olvide ejecutar el código de configuración a continuación antes de pasar a la pregunta 1.

# %%
# SETUP. You don't need to worry for now about what this code does or how it works.
# !pip install git+https://github.com/ML-Challenge/learntools.git
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex2 import *
print('Setup complete.')

# %% [markdown]
# 1.
# Complete el cuerpo de la siguiente función de acuerdo con su cadena de documentación.
#
# SUGERENCIA: Python tiene una función round integrada.

# %%
def round_to_two_places(num):
    """Return the given number rounded to two decimal places. 
    
    >>> round_to_two_places(3.14159)
    3.14
    """
    return round(num, 2)
    # Replace this body with your own code.
    # ("pass" is a keyword that does literally nothing. We used it as a placeholder
    # because after we begin a code block, Python requires at least one line of code)
    pass

# Check your answer
q1.check()

# %%
# Uncomment the following for a hint
q1.hint()
# Or uncomment the following to peek at the solution
q1.solution()

# %% [markdown]
# 2.
# La ayuda para ronda dice que los dígitos (el segundo argumento) pueden ser negativos. ¿Qué crees que pasará cuando lo sea? Pruebe algunos ejemplos en la siguiente celda.

# %%
round(3451898.14159,-3)

# %% [markdown]
# ¿Puedes pensar en un caso en el que esto sería útil? Una vez que esté listo, ejecute la celda de código a continuación para ver la respuesta y recibir crédito por completar el problema.

# %%
# Check your answer (Run this code cell to receive credit!)
#q2.solution()

# %% [markdown]
# 3.
# En el ejercicio anterior, los amigos Alice, Bob y Carol, que compartían dulces, intentaron dividir los dulces en partes iguales. Por el bien de su amistad, los dulces sobrantes serían aplastados. Por ejemplo, si en conjunto traen a casa 91 dulces, tomarán 30 cada uno y aplastarán 1.
#
# A continuación se muestra una función simple que calculará la cantidad de dulces para aplastar para cualquier cantidad de dulces en total.
#
# Modifíquelo para que, opcionalmente, tome un segundo argumento que represente la cantidad de amigos entre los que se dividen los dulces. Si no se proporciona un segundo argumento, debe suponer 3 amigos, como antes.
#
# Actualice la cadena de documentación para reflejar este nuevo comportamiento.

# %%
def to_smash(total_candies, amigos=3):
    """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between 3 friends.
    
    >>> to_smash(91)
    1
    """
    return total_candies % amigos

# Check your answer
q3.check()

# %%
q3.hint()

# %%
q3.solution()

# %% [markdown]
# 4. (Opcional)¶
# Puede que no sea divertido, pero leer y comprender los mensajes de error será una parte importante de su carrera en Python.
#
# Cada celda de código a continuación contiene un código de error comentado. Para cada celda...
#
# Lea el código y prediga lo que cree que sucederá cuando se ejecute.
# Luego descomente el código y ejecútelo para ver qué sucede. (Sugerencia: en el editor del kernel, puede resaltar varias líneas y presionar ctrl+/ para alternar entre comentarios).
# Corrija el código (para que logre su propósito previsto sin generar una excepción)

# %%
round_to_two_places = (9.9999)

# %%
x = -10
y = 5
# # Which of the two variables above has the smallest absolute value?
smallest_abs = min(abs(x), abs(y))

# %%
def f(x):
    y = abs(x)
    return y

print(f(5))
