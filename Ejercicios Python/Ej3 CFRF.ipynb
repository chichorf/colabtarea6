# %% [markdown]
# # Ejercicios
# En este ejercicio, pondrá en práctica lo que ha aprendido sobre booleanos y condicionales.
#
# Para comenzar, ejecute el código de configuración a continuación antes de escribir su propio código (y si deja este cuaderno y regresa más tarde, no olvide ejecutar el código de configuración nuevamente).

# %%
# !pip install git+https://github.com/ML-Challenge/learntools.git
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex3 import *
print('Setup complete.')

# %% [markdown]
# 1.
# Muchos lenguajes de programación tienen el signo disponible como una función integrada. Python no lo hace, ¡pero podemos definir el nuestro!
#
# En la celda a continuación, defina una función llamada signo que tome un argumento numérico y devuelva -1 si es negativo, 1 si es positivo y 0 si es 0.

# %%
# Your code goes here. Define a function called 'sign'
def sign(numero):
    if numero> 0:
        return 1
    elif numero < 0:
        return -1
    else:
        return 0
        
# Check your answer

# %%
q1.solution()

# %% [markdown]
# 2.
# Hemos decidido agregar "registro" a nuestra función to_smash del ejercicio anterior.

# %%
def to_smash(total_candies):
    """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between 3 friends.
    
    >>> to_smash(91)
    1
    """
    print("Splitting", total_candies, "candies")
    return total_candies % 3

to_smash(91)

# %%
to_smash(1)

# %% [markdown]
# ¿Qué pasa si lo llamamos con total_candies = 1?
# ¡Esa no es gran gramática!
#
# Modifique la definición en la celda a continuación para corregir la gramática de nuestra declaración de impresión. (Si solo hay un dulce, debemos usar el singular "candy" en lugar del plural "candies")

# %%
def to_smash(total_candies):
    """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between 3 friends.
    
    >>> to_smash(91)
    1
    """
    print ("Aplastando", total_candies, "dulce" if total_candies == 1 else "dulces")

    return total_candies % 3

to_smash(91)
to_smash(1)

# %% [markdown]
# Para obtener crédito por completar este problema y ver la respuesta oficial, ejecute la celda de código a continuación.

# %%
# Check your answer (Run this code cell to receive credit!)
q2.solution()

# %% [markdown]
# 3. 🌶️
# En el tutorial, hablamos sobre decidir si estamos preparados para el clima. Dije que estoy a salvo del clima de hoy si...
#
# tengo un paraguas...
# o si la lluvia no es muy fuerte y tengo capota...
# de lo contrario, sigo estando bien a menos que esté lloviendo y sea un día laboral
# La siguiente función utiliza nuestro primer intento de convertir esta lógica en una expresión de Python. Afirmé que había un error en ese código. ¿Puedes encontrarlo?
#
# Para probar que prepare_for_weather tiene errores, cree un conjunto de entradas donde:
#
# la función devuelve False (pero debería haber devuelto True), o
# la función devolvió True (pero debería haber devuelto False).
# Para obtener crédito por completar esta pregunta, su código debe arrojar un resultado Correcto.

# %%
def prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday):
    # Don't change this code. Our goal is just to find the bug, not fix it!
    return have_umbrella or rain_level < 5 and have_hood or not rain_level > 0 and is_workday

# Change the values of these inputs so they represent a case where prepared_for_weather
# returns the wrong answer.
have_umbrella = False
rain_level = 7
have_hood = True
is_workday = False

# Check what the function returns given the current values of the variables above
actual = prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday)
print(actual)

# Check your answer
q3.check()

# %%
#q3.hint()
#q3.solution(

# %% [markdown]
# 4.
# La función is_negative a continuación se implementa correctamente: devuelve True si el número dado es negativo y False en caso contrario.
#
# Sin embargo, es más detallado de lo que debe ser. De hecho, podemos reducir el número de líneas de código en esta función en un 75% manteniendo el mismo comportamiento.
#
# Vea si puede encontrar un cuerpo equivalente que use solo una línea de código y colóquelo en la función concise_is_negative. (SUGERENCIA: ni siquiera necesita la sintaxis ternaria de Python)

# %%
def is_negative(number):
    if number < 0:
        return True
    else:
        return False

def concise_is_negative(number):
    return number < 0 # Your code goes here (try to keep it to one line!)

# Check your answer
q4.check()

# %%
#q4.hint()
q4.solution()

# %% [markdown]
# 5a.
# Las variables booleanas ketchup, mostaza y cebolla representan si un cliente quiere un aderezo particular para su perrito caliente. Queremos implementar una serie de funciones booleanas que correspondan a algunas preguntas de sí o no sobre el pedido del cliente. Por ejemplo:

# %%
def onionless(ketchup, mustard, onion):
    """Return whether the customer doesn't want onions.
    """
    return not onion

# %%
def wants_all_toppings(ketchup, mustard, onion):
    """Return whether the customer wants "the works" (all 3 toppings)
    """
    return ketchup and mustard and onion

# Check your answer
q5.a.check()

# %%
#q5.a.solution()

# %% [markdown]
# 5b.
# Para la siguiente función, complete el cuerpo para que coincida con la descripción en inglés en la cadena de documentación.

# %%
def wants_plain_hotdog(ketchup, mustard, onion):
    """Return whether the customer wants a plain hot dog with no toppings.
    """
    return not ketchup and not mustard and not onion

# Check your answer
q5.b.check()

# %%
#q5.b.hint()
#q5.b.solution()

# %% [markdown]
# 5c.
# Ya sabe qué hacer: para la siguiente función, complete el cuerpo para que coincida con la descripción en inglés en la cadena de documentación.

# %%
def exactly_one_sauce(ketchup, mustard, onion):
    """Return whether the customer wants either ketchup or mustard, but not both.
    (You may be familiar with this operation under the name "exclusive or")
    """
    return (ketchup or mustard) and not (ketchup and mustard)

# Check your answer
q5.c.check()

# %%
#q5.c.hint()
#q5.c.solution()

# %% [markdown]
# 6. 🌶️
# Hemos visto que llamar a bool() en un número entero devuelve False si es igual a 0 y True en caso contrario. ¿Qué sucede si llamamos a int() en un bool? Pruébelo en la celda del cuaderno a continuación.
#
# ¿Puedes aprovechar esto para escribir una función sucinta que corresponda a la oración en inglés "¿quiere el cliente exactamente un aderezo?"?

# %%
def exactly_one_topping(ketchup, mustard, onion):
    """Return whether the customer wants exactly one of the three available toppings
    on their hot dog.
    """
    return (ketchup + mustard + onion) ==1

# Check your answer
q6.check()

# %%
#q6.hint()
#q6.solution()

# %% [markdown]
# 7. 🌶️ (Opcional)
# En este problema, trabajaremos con una versión simplificada del blackjack (también conocido como veintiuno). En esta versión hay un jugador (a quien controlarás) y un crupier. El juego procede de la siguiente manera:
#
# El jugador recibe dos cartas boca arriba. El crupier recibe una carta boca arriba.
# El jugador puede pedir que se le reparta otra carta ('hit') tantas veces como desee. Si la suma de sus cartas supera los 21, pierden la ronda inmediatamente.
# Luego, el crupier se reparte cartas adicionales a sí mismo hasta que:
# la suma de las cartas del crupier excede 21, en cuyo caso el jugador gana la ronda
# la suma de las cartas del crupier es mayor o igual a 17. Si el total del jugador es mayor que el del crupier, el jugador gana. De lo contrario, el crupier gana (incluso en caso de empate).
# Al calcular la suma de las cartas, Jota, Reina y Rey cuentan como 10. Los ases pueden contar como 1 u 11 (cuando nos referimos al "total" de un jugador arriba, nos referimos al total más grande que se puede hacer sin exceder 21. Por ejemplo, A+8 = 19, A+8+8 = 17)
#
# Para este problema, escribirá una función que represente la estrategia de toma de decisiones del jugador en este juego. Hemos proporcionado una implementación muy poco inteligente a continuación:

# %%
def should_hit(dealer_total, player_total, player_low_aces, player_high_aces):
    """Return True if the player should hit (request another card) given the current game
    state, or False if the player should stay.
    When calculating a hand's total value, we count aces as "high" (with value 11) if doing so
    doesn't bring the total above 21, otherwise we count them as low (with value 1). 
    For example, if the player's hand is {A, A, A, 7}, we will count it as 11 + 1 + 1 + 7,
    and therefore set player_total=20, player_low_aces=2, player_high_aces=1.
    """
    return False

# %% [markdown]
# Este agente muy conservador siempre se queda con la mano de dos cartas que le reparten.
#
# Estaremos simulando juegos entre su agente jugador y nuestro propio agente repartidor llamando a su función.
#
# Intente ejecutar la siguiente función para ver un ejemplo de un juego simulado:

# %%
q7.simulate_one_game()

# %% [markdown]
# La verdadera prueba del temple de su agente es su tasa de ganancias promedio en muchos juegos. Intente llamar a la siguiente función para simular 50000 juegos de blackjack (puede tardar un par de segundos):

# %%
q7.simulate(n_games=50000)

# %% [markdown]
# ¡Nuestro agente tonto que ignora por completo el estado del juego aún logra ganar sorprendentemente a menudo!
#
# Intente agregar más inteligencia a la función should_hit y vea cómo afecta los resultados.

# %%
def should_hit(dealer_total, player_total, player_low_aces, player_high_aces):
    """Return True if the player should hit (request another card) given the current game
    state, or False if the player should stay.
    When calculating a hand's total value, we count aces as "high" (with value 11) if doing so
    doesn't bring the total above 21, otherwise we count them as low (with value 1). 
    For example, if the player's hand is {A, A, A, 7}, we will count it as 11 + 1 + 1 + 7,
    and therefore set player_total=20, player_low_aces=2, player_high_aces=1.
    """
    return False

q7.simulate(n_games=50000)
