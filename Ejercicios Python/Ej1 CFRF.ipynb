# %% [markdown]
# # Ejercicios
# Bienvenido a su primer conjunto de problemas de codificación de Python. Si es la primera vez que usa Kaggle Notebooks, ¡bienvenido!
#
# Los cuadernos están compuestos por bloques (llamados "celdas") de texto y código. Cada uno de estos es editable, aunque principalmente editará las celdas de código para responder algunas preguntas.
#
# Para comenzar, intente ejecutar la celda de código a continuación (presionando el botón ► o haciendo clic en la celda y presionando ctrl+enter en su teclado).

# %%
print("You've successfully run some Python code")
print("Congratulations!")
# Out:
# You've successfully run some Python code
# Congratulations!

# %% [markdown]
# Intente agregar otra línea de código en la celda de arriba y vuelva a ejecutarla.
#
# Ahora seamos un poco más sofisticados: agregue una nueva celda de código haciendo clic en una celda de código existente, presionando la tecla escape y luego presionando la tecla a o b. La tecla a agregará una celda arriba de la celda actual y la tecla b agregará una celda debajo.
#
# ¡Estupendo! Ahora ya sabes cómo usar Notebooks.
#
# Cada ejercicio práctico comienza con la configuración de nuestro mecanismo de verificación de código y retroalimentación. Ejecute la celda de código a continuación para hacer eso. Entonces estará listo para pasar a la pregunta 0.

# %%
# !pip install git+https://github.com/ML-Challenge/learntools.git
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex1 import *
print("Setup complete! You're ready to start question 0.")

# %% [markdown]
# 0.
# Esta es una pregunta tonta que pretende ser una introducción al formato que usamos para los ejercicios prácticos en todos los cursos de Kaggle.
#
# *¿Cuál es tu color favorito? *
#
# Para completar esta pregunta, cree una variable llamada color en la celda de abajo con un valor apropiado. La llamada de función q0.check() (que ya proporcionamos en la celda a continuación) verificará su respuesta.

# %%
# create a variable called color with an appropriate value on the line below
# (Remember, strings in Python must be enclosed in 'single' or "double" quotes)
color = "blue"
# Check your answer
q0.check()
# Out:
# Correct

# %% [markdown]
# ¿No obtuviste la respuesta correcta? ¡¿Cómo es que ni siquiera sabes cuál es tu color favorito?!
#
# Elimine el # en la línea a continuación para hacer que una de las líneas se ejecute. Puede elegir entre obtener una pista o la respuesta completa eligiendo de qué línea quitar el #.
#
# Eliminar el # se llama descomentar, porque cambia esa línea de un "comentario" que Python no ejecuta a código, que Python sí ejecuta.

# %%
#q0.hint()
#q0.solution()

# %% [markdown]
# 1.
# Complete el código a continuación. En caso de que sea útil, aquí está la tabla de operaciones aritméticas disponibles:
#
# Operador Nombre Descripción
# a + b Adición Suma de a y b
# a - b Resta Diferencia de a y b
# a * b Producto de multiplicación de a y b
# a / b División verdadera Cociente de a y b
# a // b División de piso Cociente de a y b, eliminando partes fraccionarias
# a % b Módulo Resto entero después de la división de a por b
# a ** b Exponenciación a elevada a la potencia de b
# -a Negación El negativo de a

# %%
pi = 3.14159 # approximate
diameter = 3
​
# Create a variable called 'radius' equal to half the diameter
radius = diametro/2
​
​
# Create a variable called 'area', using the formula for the area of a circle: pi times the radius squared
area = pi * radius**2
​
# Check your answer
q1.check()

# %%
# Uncomment and run the lines below if you need help.
q1.hint()
q1.solution()

# %% [markdown]
# 2.
# Agregue código a la siguiente celda para intercambiar las variables a y b (de modo que a se refiera al objeto al que antes hacía referencia b y viceversa).

# %%
########### Setup code - don't touch this part ######################
# If you're curious, these are examples of lists. We'll talk about 
# them in depth a few lessons from now. For now, just know that they're
# yet another type of Python object, like int or float.
a = [1, 2, 3]
b = [3, 2, 1]
q2.store_original_ids()
######################################################################

# Your code goes here. Swap the values to which a and b refer.
# If you get stuck, you can always uncomment one or both of the lines in
# the next cell for a hint, or to peek at the solution.
c=a
a=b
b=c
######################################################################

# Check your answer
q2.check()

# %%
q2.hint()

# %%
q2.solution()

# %% [markdown]
# 3a.
# Agregue paréntesis a la siguiente expresión para que evalúe a 1.

# %%
(5 - 3) // 2

# %%
#q3.a.hint()

# %%
# Check your answer (Run this code cell to receive credit!)
q3.a.solution()

# %% [markdown]
# 3b. 🌶️¶
# Las preguntas, como esta, marcadas con un pimiento picante son un poco más difíciles.
#
# Agregue paréntesis a la siguiente expresión para que evalúe a 0.

# %%
8 - (3 * 2 )- (1 + 1)

# %%
#q3.b.hint()

# %%
# Check your answer (Run this code cell to receive credit!)
q3.b.solution()

# %% [markdown]
# 4.
# Alice, Bob and Carol have agreed to pool their Halloween candy and split it evenly among themselves. For the sake of their friendship, any candies left over will be smashed. For example, if they collectively bring home 91 candies, they'll take 30 each and smash 1.
#
# Write an arithmetic expression below to calculate how many candies they must smash for a given haul.

# %%
# Variables representing the number of candies collected by alice, bob, and carol
alice_candies = 121
bob_candies = 77
carol_candies = 109
total= alice_candies + bob_candies + carol_candies

# Your code goes here! Replace the right-hand side of this assignment with an expression
# involving alice_candies, bob_candies, and carol_candies

total=total%3
to_smash = total

# Check your answer
q4.check()

# %%
#q4.hint()
q4.solution()
