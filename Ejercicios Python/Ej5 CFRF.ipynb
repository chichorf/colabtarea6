# %% [markdown]
# # Ejercicios
# Con todo lo que has aprendido, puedes empezar a escribir programas mucho más interesantes. Vea si puede resolver los siguientes problemas.
#
# Como siempre, ejecute el código de configuración a continuación antes de trabajar en las preguntas.

# %%
# !pip install git+https://github.com/ML-Challenge/learntools.git
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex5 import *
print('Setup complete.')

# %% [markdown]
# 1.
# ¿Alguna vez ha sentido que la depuración implicaba un poco de suerte? El siguiente programa tiene un error. Intente identificar el error y solucionarlo.

# %%
def has_lucky_number(nums):
    """Return whether the given list of numbers is lucky. A lucky list contains
    at least one number divisible by 7.
    """
    for num in nums:
        if num % 7 == 0:
            return True
        else:
            return False

# %% [markdown]
# Intente identificar el error y corríjalo en la siguiente celda:

# %%
def has_lucky_number(nums):
    """Return whether the given list of numbers is lucky. A lucky list contains
    at least one number divisible by 7.
    """
    
    return any([num % 7 == 0 for num in nums])

# Check your answer
q1.check()

# %%
#q1.hint()
q1.solution()

# %% [markdown]
# 2.
# Mire la expresión de Python a continuación. ¿Qué crees que obtendremos cuando lo ejecutemos? Cuando haya hecho su predicción, descomente el código y ejecute la celda para ver si tenía razón.

# %%
[1, 2, 3, 4] > 2

# %% [markdown]
# R y Python tienen algunas bibliotecas (como numpy y pandas) comparan cada elemento de la lista con 2 (es decir, hacen una comparación 'elementalmente') y nos dan una lista de valores booleanos como [False, False, True, True].
#
# Implemente una función que reproduzca este comportamiento, devolviendo una lista de booleanos correspondientes a si el elemento correspondiente es mayor que n.

# %%
def elementwise_greater_than(L, thresh):
    """Return a list with the same length as L, where the value at index i is 
    True if L[i] is greater than thresh, and False otherwise.
    
    >>> elementwise_greater_than([1, 2, 3, 4], 2)
    [False, False, True, True]
    """
    return [element > thresh for element in L]

# Check your answer
q2.check()

# %%
#q2.solution()

# %% [markdown]
# 3.
# Complete el cuerpo de la función a continuación de acuerdo con su cadena de documentación.

# %%
def menu_is_boring(meals):
    """Given a list of meals served over some period of time, return True if the
    same meal has ever been served two days in a row, and False otherwise.
    """
    for i in range(len(meals)-1):
        if meals [i] == meals[i+1]:
            return True
    return False

# Check your answer
q3.check()

# %%
#q3.hint()
q3.solution()

# %% [markdown]
# 4. 🌶️
# Junto a la mesa de Blackjack, el Python Challenge Casino tiene una máquina tragamonedas. Puede obtener un resultado de la máquina tragamonedas llamando a play_slot_machine(). El número que devuelve son sus ganancias en dólares. Por lo general, devuelve 0. Pero a veces tendrás suerte y obtendrás un gran día de pago. Intenta ejecutarlo a continuación:

# %%
play_slot_machine()

# %% [markdown]
# agregar códigoagregar Markdown
# Por cierto, ¿mencionamos que cada jugada cuesta $1? No te preocupes, te enviaremos la factura más tarde.
#
# En promedio, ¿cuánto dinero puede esperar ganar (o perder) cada vez que juega en la máquina? El casino lo mantiene en secreto, pero puedes estimar el valor promedio de cada tirada utilizando una técnica llamada método Monte Carlo. Para estimar el resultado promedio, simulamos el escenario muchas veces y devolvemos el resultado promedio.
#
# Complete la siguiente función para calcular el valor promedio por jugada de la máquina tragamonedas.

# %%
def estimate_average_slot_payout(n_runs):
    """Run the slot machine n_runs times and return the average net profit per run.
    Example calls (note that return value is nondeterministic!):
    >>> estimate_average_slot_payout(1)
    -1
    >>> estimate_average_slot_payout(1)
    0.5
    """
    payouts = [play_slot_machine()-1 for i in range(n_runs)]
    avg_payout = sum(payouts) / n_runs
    return avg_payout
estimate_average_slot_payout(10000000)

# %% [markdown]
# Cuando crea que conoce el valor esperado por giro, ejecute la celda de código a continuación para ver la solución y obtener crédito por responder la pregunta.

# %%
# Check your answer (Run this code cell to receive credit!)
q4.solution()
